# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# %%
from huggingface_hub import snapshot_download
model_id = "mistralai/Mistral-7B-Instruct-v0.1"
local_dir = snapshot_download(model_id, cache_dir="/projectnb/cs523aw/students/erioe/model_cache/")
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
tokenizer = AutoTokenizer.from_pretrained(local_dir)
model = AutoModelForCausalLM.from_pretrained(
    local_dir,
    dtype=torch.bfloat16,  # 也可用 float16
    device_map="auto"
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
def query_movie(movie_title):
    prompt = f"""<s>[INST] Answer the following:
1. Is the movie "{movie_title}" an animated film or a live-action film?
2. List the top 10 main actors or voice actors of the movie. [/INST]"""

    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    output = model.generate(**inputs, max_new_tokens=300)
    response = tokenizer.decode(output[0], skip_special_tokens=True)
    return response.split("[/INST]")[-1].strip()
print(query_movie("Toy Story (1995)"))
print(query_movie("The Dark Knight (2008)"))

# %%
print(query_movie("Toy Story (1995)"))
print(query_movie("The Dark Knight (2008)"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# 1. The movie "Toy Story (1995)" is an animated film.
#
# 2. The top 10 main actors or voice actors of the movie are:
#    - Tom Hanks as Woody
#    - Tim Allen as Buzz Lightyear
#    - Laurie Metcalf as Andy's Mom
#    - James Earl Jones as Mufasa
#    - Robin Williams as Al
#    - John Goodman as Rex
#    - Whoopi Goldberg as Jessie
#    - Samuel L. Jackson as Ham
#    - Nick Robinson as Woody's Kid
#    - Jim Cummings as Slinky
# 1. The movie "The Dark Knight (2008)" is a live-action film.
# 2. The top 10 main actors or voice actors of the movie are:
#    - Christian Bale as Batman
#    - Heath Ledger as The Joker
#    - Aaron Eckhart as Harvey Dent
#    - Michael Caine as Alfred Pennyworth
#    - Gary Oldman as Commissioner Gordon
#    - Morgan Freeman as Lucius Fox
#    - Michael Clarke Duncan as John Wayne Gotham
#    - Chrissy Metz as Ivy Pryce
#    - Aaron Eckhart as Harvey Dent
#    - Joseph Gordon-Levitt as Gotham City Police Department Lieutenant James Gordon.
